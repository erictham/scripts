# %% [markdown]
# ## DataFusion Restful API in Python

# %% [markdown]
# This documentation describes the DataFusion, a triples stores database from Thomson Reuters. DataFusion is a graphical database that uses the RDF format. RDF stands for Resource Document Format and is a form of serialisation for the triples store.
#
# It is divided into the sections:
# 1. Graphical database concepts
# 2. RDF vs Neo4j
# 3. How to search in DataFusion
# 2. DataFusion RESTFUL API concepts
# 3. Glossary :
#     i.   concepts
#     ii.  tokens
#     iii. properties
#     iv.  relationships
#     v.   entities
#     vi.  annotations
#     vii. documents
#     viii.
#
#
# The documentation is not meant to be exhaustive with ongoing revisions. This notebook works in an iPython notebook. Python code in the cells are executed by pressing "Shift-Enter".

# %% [markdown]
# ### Graphical Database concepts

# %% [markdown]
# A graphical database uses a graph or network structure to hold nodes, edges and properties. Nodes are entities in the graphs which are described by the properties. The nodes are then connected to one another through edges.
#
# This form of modelling reflects the typical relationships in the real world, as compared to the relational databases. To visulaise the difference between a RDMS and a graphical database, imagine a RDMS as a cube whilst a graphical database as an oddly-shaped sphere. A cube has fixed links between its edges, and add-on cubes can be added on a fixed side. In a sphere, there additional entities can be placed anywhere in the sphere.
#
# The graphical databases reflect inter-relationships in the real world. These relationships are used in the financial sector in areas ranging from [risk stress testing](http://as.wiley.com/WileyCDA/WileyTitle/productCd-0470666013.html), compliance and risks, [credit risks network monitoring](http://dbsreuters.s3-website-ap-southeast-1.amazonaws.com/), hierarchical relationships modelling, [geopolitical risk dashboard](http://datalab.int.thomsonreuters.com:3838/jr/pro-risk/) and [thirty party risk monitoring](http://datalab.int.thomsonreuters.com/bromer/3pr/).
#
# Neo4j is a commonly used product in the market for graph database - the Panama Papers were built on Neo4j. There are notable differences between the Neo4j and the *RDF*.
#
#
# #### RDF vs Neo4j
# A RDF is a triples stores consisting of an subject, predicate and object. In a statement, "Thomas bought 30 thousands of Apple Shares', the subject is "Thomas", the predicate is the action verb "bought" whilst the object is the '30 thousands of Apple shares'.
#
# DataFusion has an additional quad store with annotations that contains the properties of the edges. This
#
# #### Thomson Reuters DataFusion

# %% [markdown]
# ### Using DataFusion:
# The DataFusion API reflects the DataFusion functionalities on its web interface. It can be used for string searches, finding of relationships amongst entities, listing of properties and the upload of data sources. It can further be used for the annotations which are 'properties' defined for edges, that is not available on the web interface.
#
# A context in DataFusion is synomynous with a datasource. DataSources can be created on the DataFusion interface for different database format eg. RDF, delimited and RDMS. Being a default RDF database, DataFusion is most expressive in this format with relationships and entities. It is expected that client applications will involve coding to transform other database sources to RDF for the input of data.
#
# #### Contextual Lists
#
# Contexts are retrieved by the following RESTFUL API. Note that the response.status_code returns the HTTP return code. A code of 200 indicates successful retrieval of data. HTML codes can be referenced in the [link](https://www.w3.org/Protocols/rfc2616/rfc2616-sec10.html).
# Common errors include 404 - data is not found and 400 - bad request.

# %%
import requests

# Obtain contextual lists:
url_dds_test = "http://dds-test.thomsonreuters.com/app/api/context/list"
url_dds = "https://dds.thomsonreuters.com/app/api/context/list"

def retURL(url):
    headers = {  'Content-Type': 'application/json'   , 'Authorization' : 'Bearer hboalirnc3d4n04phhvv2bas8fdjd6h9' } 
    response = requests.get(url, headers=headers)
    
    try:
        if response.status_code <> 200:
            raise ValueError('Error in HTTP ')
        else:
            data = response.json()  # output is in Python list
            print 'HTTP request is successful with code ' + str(response.status_code )
    except:
        print 'Error in HTTP call ' + str(response.status_code )
        data = ""
    return data

retURL(url_dds_test)
# Out:
# HTTP request is successful with code 200
# [{u'id': 43,
#   u'jdbcRepository': None,
#   u'lastBatchReceived': u'2016-06-08T15:12:02Z',
#   u'name': u'msft_poc',
#   u'predicates': [{u'id': 14230,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.series_season.to'},
#    {u'id': 14141,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.consumer_company.brands'},
#    {u'id': 14159,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.combined_fuel_economy_minimum'},
#    {u'id': 13755,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.game_version.developer'},
#    {u'id': 13808,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.income_share_lowest_20_percent'},
#    {u'id': 14262,
#     u'uri': u'http://knowledge.microsoft.com/mso/games.game.publisher'},
#    {u'id': 14676,
#     u'uri': u'http://knowledge.microsoft.com/mso/book.written_work.next_in_series'},
#    {u'id': 14231,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.series_season.previous_season'},
#    {u'id': 14052,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.female_children_in_employment_study_work'},
#    {u'id': 14520,
#     u'uri': u'http://knowledge.microsoft.com/mso/film.film.director'},
#    {u'id': 13591,
#     u'uri': u'http://knowledge.microsoft.com/ext/entity_richness.rich_entity'},
#    {u'id': 14358,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.disease.icd_9'},
#    {u'id': 14238,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.relationship.parent'},
#    {u'id': 13891,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.government_group.public_deficit_surplus'},
#    {u'id': 14683,
#     u'uri': u'http://knowledge.microsoft.com/mso/government.political_ideology.political_parties'},
#    {u'id': 14687,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.sponsorship.sponsored_by'},
#    {u'id': 14826,
#     u'uri': u'http://knowledge.microsoft.com/mso/commerce.electronics_product.user_memory'},
#    {u'id': 15170,
#     u'uri': u'http://knowledge.microsoft.com/mso/education.academic.field_of_study'},
#    {u'id': 14884,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.model.model_years'},
#    {u'id': 13721,
#     u'uri': u'http://knowledge.microsoft.com/mso/travel.destination.tourist_attraction'},
#    {u'id': 13961,
#     u'uri': u'http://knowledge.microsoft.com/mso/award.category.winners'},
#    {u'id': 13982,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.health_group.measles_immunization'},
#    {u'id': 14044,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.depth_of_credit_information_index'},
#    {u'id': 14597,
#     u'uri': u'http://knowledge.microsoft.com/mso/sports.team_owner.teams_owned'},
#    {u'id': 13558,
#     u'uri': u'http://knowledge.microsoft.com/mso/type.object.key'},
#    {u'id': 14209,
#     u'uri': u'http://knowledge.microsoft.com/mso/time.daylight_saving_time.policy_begin'},
#    {u'id': 14169,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.model_year.market'},
#    {u'id': 15169,
#     u'uri': u'http://knowledge.microsoft.com/mso/education.academic.advisors'},
#    {u'id': 14934,
#     u'uri': u'http://knowledge.microsoft.com/mso/film.film.story'},
#    {u'id': 14125,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.board_member.organization_board_memberships'},
#    {u'id': 14913,
#     u'uri': u'http://knowledge.microsoft.com/mso/time.event.includes'},
#    {u'id': 13722,
#     u'uri': u'http://knowledge.microsoft.com/mso/award.presenting_organization.award_categories_presented'},
#    {u'id': 15168,
#     u'uri': u'http://knowledge.microsoft.com/mso/education.academic.advisees'},
#    {u'id': 14451,
#     u'uri': u'http://knowledge.microsoft.com/mso/ratings.rated_entity.rating_scale'},
#    {u'id': 15096,
#     u'uri': u'http://knowledge.microsoft.com/mso/computer.programming_language.dialects'},
#    {u'id': 14652,
#     u'uri': u'http://knowledge.microsoft.com/mso/computer.operating_system.parent_os'},
#    {u'id': 14393,
#     u'uri': u'http://knowledge.microsoft.com/mso/food.recipe_author.recipes'},
#    {u'id': 14558,
#     u'uri': u'http://knowledge.microsoft.com/mso/education.honorary_degree_recipient.honorary_degrees'},
#    {u'id': 14318,
#     u'uri': u'http://knowledge.microsoft.com/mso/measurement_unit.money_value.amount'},
#    {u'id': 14429,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.computer_videogame.characters'},
#    {u'id': 13616,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.person.parent'},
#    {u'id': 14091,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.urban_poverty_headcount_ratio_national_poverty_lines'},
#    {u'id': 13890,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.education_group.female_primary_completion_rate'},
#    {u'id': 14866,
#     u'uri': u'http://knowledge.microsoft.com/mso/geography.mountain.mountain_range'},
#    {u'id': 15008,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.game_series.games_in_series'},
#    {u'id': 15061,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.spun_off_from'},
#    {u'id': 13830,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.environment_group.threatened_mammal_species'},
#    {u'id': 14012,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.government_group.direct_nonresident_trademark_applications'},
#    {u'id': 14311,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.merger'},
#    {u'id': 14885,
#     u'uri': u'http://knowledge.microsoft.com/mso/music.album.artist'},
#    {u'id': 15058,
#     u'uri': u'http://knowledge.microsoft.com/mso/broadcast.radio_station.owner'},
#    {u'id': 13708,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.minimum_wage'},
#    {u'id': 14401,
#     u'uri': u'http://knowledge.microsoft.com/mso/geography.island_group.major_islands'},
#    {u'id': 14636,
#     u'uri': u'http://knowledge.microsoft.com/mso/commerce.consumer_product.dimensions'},
#    {u'id': 14823,
#     u'uri': u'http://knowledge.microsoft.com/mso/commerce.consumer_product.successor'},
#    {u'id': 13869,
#     u'uri': u'http://knowledge.microsoft.com/mso/film.director.film'},
#    {u'id': 14692,
#     u'uri': u'http://knowledge.microsoft.com/mso/language.human_language.culture_code'},
#    {u'id': 14605,
#     u'uri': u'http://knowledge.microsoft.com/mso/commerce.brand.parent_brand'},
#    {u'id': 15199,
#     u'uri': u'http://knowledge.microsoft.com/ext/entity_datagroup'},
#    {u'id': 15201,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.medical_trial_sponsor.trials_sponsored'},
#    {u'id': 13733,
#     u'uri': u'http://knowledge.microsoft.com/mso/travel.tourist_attraction.read_guidebook'},
#    {u'id': 14414,
#     u'uri': u'http://knowledge.microsoft.com/mso/venture_capital.venture_funded_company.venture_investors'},
#    {u'id': 14443,
#     u'uri': u'http://knowledge.microsoft.com/mso/media_common.creative_work.content_rating'},
#    {u'id': 14870,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.program.soundtrack'},
#    {u'id': 13633,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.location'},
#    {u'id': 14448,
#     u'uri': u'http://knowledge.microsoft.com/mso/fictional_universe.work_of_fiction.part_of_these_fictional_universes'},
#    {u'id': 13817,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.infrastructure_group.improved_sanitation_facilities'},
#    {u'id': 13948,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.deposit_interest_rate'},
#    {u'id': 15230,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.producer_term.program'},
#    {u'id': 13866,
#     u'uri': u'http://knowledge.microsoft.com/mso/location.sovereign.iso4217_currency_code'},
#    {u'id': 14985,
#     u'uri': u'http://knowledge.microsoft.com/ext/Type.object.subject_key'},
#    {u'id': 14303,
#     u'uri': u'http://knowledge.microsoft.com/csgaction/action_button.action'},
#    {u'id': 13745,
#     u'uri': u'http://knowledge.microsoft.com/mso/architecture.architect.structure'},
#    {u'id': 13998,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.government_group.time_prepare_taxes'},
#    {u'id': 15110,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.computer_videogame.processors_supported'},
#    {u'id': 15055,
#     u'uri': u'http://knowledge.microsoft.com/mso/chemistry.chemical_compound.melting_point'},
#    {u'id': 14109,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.refugee_population_by_origin_region'},
#    {u'id': 14162,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.ad_category'},
#    {u'id': 13756,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.game_version.release_date'},
#    {u'id': 14502,
#     u'uri': u'http://knowledge.microsoft.com/mso/film.film.production_company'},
#    {u'id': 13955,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.total_vulnerable_employment'},
#    {u'id': 13976,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.education_group.ratio_female_male_primary'},
#    {u'id': 13764,
#     u'uri': u'http://knowledge.microsoft.com/mso/music.musician.group_membership'},
#    {u'id': 15198,
#     u'uri': u'http://knowledge.microsoft.com/mso/sports.team.coach'},
#    {u'id': 13768,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.net_flows_long_term_external_debt'},
#    {u'id': 15091,
#     u'uri': u'http://knowledge.microsoft.com/mso/film.film.prequel'},
#    {u'id': 13789,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.health_group.physicians_per_thousand'},
#    {u'id': 14391,
#     u'uri': u'http://knowledge.microsoft.com/csgaction/action.category'},
#    {u'id': 14300,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.operation.current_assets'},
#    {u'id': 14029,
#     u'uri': u'http://knowledge.microsoft.com/mso/location.sovereign.national_anthem_of_a_country'},
#    {u'id': 13742,
#     u'uri': u'http://knowledge.microsoft.com/mso/government.governmental_body.members'},
#    {u'id': 14570,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.dissolved_date'},
#    {u'id': 13729,
#     u'uri': u'http://knowledge.microsoft.com/mso/event.agent.owner'},
#    {u'id': 13695,
#     u'uri': u'http://knowledge.microsoft.com/mso/symbols.namesake.named_after'},
#    {u'id': 13944,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.education_group.female_gross_intake_ratio'},
#    {u'id': 13785,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.environment_group.renewable_freshwater_per_capita'},
#    {u'id': 14239,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.relationship.child'},
#    {u'id': 14173,
#     u'uri': u'http://knowledge.microsoft.com/mso/commerce.consumer_product.company'},
#    {u'id': 14150,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.area_served'},
#    {u'id': 14476,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.program.seasons'},
#    {u'id': 13713,
#     u'uri': u'http://knowledge.microsoft.com/mso/film.subject.film'},
#    {u'id': 14813,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.spin_offs'},
#    {u'id': 14164,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.related'},
#    {u'id': 15088,
#     u'uri': u'http://knowledge.microsoft.com/mso/military.armed_force.units'},
#    {u'id': 14336,
#     u'uri': u'http://knowledge.microsoft.com/mso/award.honor.year'},
#    {u'id': 14112,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.make.model'},
#    {u'id': 13576,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.series_episode.program'},
#    {u'id': 14773,
#     u'uri': u'http://knowledge.microsoft.com/mso/language.human_language.dialect'},
#    {u'id': 14022,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.net_oda_and_official_aid_received'},
#    {u'id': 14795,
#     u'uri': u'http://knowledge.microsoft.com/mso/education.online_course.field_of_study'},
#    {u'id': 14638,
#     u'uri': u'http://knowledge.microsoft.com/productsearch/commerce.consumer_product.metaword'},
#    {u'id': 14765,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.role.governors'},
#    {u'id': 14399,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.person.height'},
#    {u'id': 14669,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.company_product_relationship.company'},
#    {u'id': 15171,
#     u'uri': u'http://knowledge.microsoft.com/mso/games.game.expansions'},
#    {u'id': 15043,
#     u'uri': u'http://knowledge.microsoft.com/mso/soccer.pitch.matches'},
#    {u'id': 14872,
#     u'uri': u'http://knowledge.microsoft.com/dev/local.entity.operating_hour'},
#    {u'id': 15072,
#     u'uri': u'http://knowledge.microsoft.com/dev/ratings.rated_entity.provided_aggregate_rating'},
#    {u'id': 14953,
#     u'uri': u'http://knowledge.microsoft.com/mso/music.album.record_label'},
#    {u'id': 14120,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.firms_bank_financed_investment'},
#    {u'id': 14938,
#     u'uri': u'http://knowledge.microsoft.com/mso/time.event.location'},
#    {u'id': 14619,
#     u'uri': u'http://knowledge.microsoft.com/mso/computer.operating_system.operating_system_developer'},
#    {u'id': 13657,
#     u'uri': u'http://knowledge.microsoft.com/mso/book.author.openlibrary_id'},
#    {u'id': 14229,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.series_season.number_of_episodes'},
#    {u'id': 13594,
#     u'uri': u'http://knowledge.microsoft.com/ext/infobox_person.residence'},
#    {u'id': 13797,
#     u'uri': u'http://knowledge.microsoft.com/mso/biology.breed_origin.animal_breed'},
#    {u'id': 14762,
#     u'uri': u'http://knowledge.microsoft.com/mso/food.nutrition.nutrient'},
#    {u'id': 14699,
#     u'uri': u'http://knowledge.microsoft.com/mso/local.entity.disabled'},
#    {u'id': 14830,
#     u'uri': u'http://knowledge.microsoft.com/mso/commerce.consumer_product.warranty'},
#    {u'id': 13838,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.time_to_start_business'},
#    {u'id': 14408,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.drug_class.drugs'},
#    {u'id': 13967,
#     u'uri': u'http://knowledge.microsoft.com/mso/royalty.kingdom.rulers'},
#    {u'id': 14458,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.drug.drug_administration'},
#    {u'id': 14780,
#     u'uri': u'http://knowledge.microsoft.com/mso/language.human_language.countries_spoken_in'},
#    {u'id': 14416,
#     u'uri': u'http://knowledge.microsoft.com/dev/common.image.is_wikipedia_infobox'},
#    {u'id': 14501,
#     u'uri': u'http://knowledge.microsoft.com/mso/common.text.tokenized_content'},
#    {u'id': 14023,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.infrastructure_group.energy_use_per_capita'},
#    {u'id': 14553,
#     u'uri': u'http://knowledge.microsoft.com/mso/government.politician.party'},
#    {u'id': 14853,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.disease.prevention_factor_free_text'},
#    {u'id': 13971,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.child_labor'},
#    {u'id': 14512,
#     u'uri': u'http://knowledge.microsoft.com/mso/film.film.distribution'},
#    {u'id': 15016,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.program.subjects'},
#    {u'id': 14583,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.length'},
#    {u'id': 15077,
#     u'uri': u'http://knowledge.microsoft.com/mso/law.attorney.bing_category'},
#    {u'id': 14227,
#     u'uri': u'http://knowledge.microsoft.com/mso/computer.software.latest_release_date'},
#    {u'id': 14149,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.defunct_company.reason_for_ceasing_operations'},
#    {u'id': 14441,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.computer_videogame.genre'},
#    {u'id': 14333,
#     u'uri': u'http://knowledge.microsoft.com/mso/award.honor.winner'},
#    {u'id': 14849,
#     u'uri': u'http://knowledge.microsoft.com/mso/film.film.sequel'},
#    {u'id': 15203,
#     u'uri': u'http://knowledge.microsoft.com/mso/book.author.series_written_or_contributed_to'},
#    {u'id': 14940,
#     u'uri': u'http://knowledge.microsoft.com/mso/internet.social_network_user.social_network_size'},
#    {u'id': 13964,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.education_group.ratio_female_male_primary_secondary'},
#    {u'id': 13923,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.real_gdp'},
#    {u'id': 14610,
#     u'uri': u'http://knowledge.microsoft.com/mso/ratings.rated_entity.weighted_aggregate_rating'},
#    {u'id': 13980,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.net_migration_rate'},
#    {u'id': 13796,
#     u'uri': u'http://knowledge.microsoft.com/mso/sports.country.multi_event_tournaments_participated_in'},
#    {u'id': 13632,
#     u'uri': u'http://knowledge.microsoft.com/mso/location.location.geolocation'},
#    {u'id': 15143,
#     u'uri': u'http://knowledge.microsoft.com/mso/broadcast.radio_station.founded'},
#    {u'id': 13559,
#     u'uri': u'http://knowledge.microsoft.com/mso/type.object.type'},
#    {u'id': 13676,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.drug_brand.active_ingredients'},
#    {u'id': 13957,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.personal_remittances_received'},
#    {u'id': 14313,
#     u'uri': u'http://knowledge.microsoft.com/mso/visual_art.artwork.artist'},
#    {u'id': 14545,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.deceased_person.cause_of_death'},
#    {u'id': 15040,
#     u'uri': u'http://knowledge.microsoft.com/mso/education.academic_institution.visiting_scholars_fellows_etc'},
#    {u'id': 14179,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.overall_rating'},
#    {u'id': 13717,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.population_by_demographics'},
#    {u'id': 14708,
#     u'uri': u'http://knowledge.microsoft.com/local/local.entity.identifier'},
#    {u'id': 13663,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.customer.supplier'},
#    {u'id': 13842,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.external_debt_stock_private_nonguaranteed'},
#    {u'id': 14695,
#     u'uri': u'http://knowledge.microsoft.com/local/ratings.rated_entity.provided_aggregate_rating'},
#    {u'id': 14861,
#     u'uri': u'http://knowledge.microsoft.com/mso/book.translated_work.translation'},
#    {u'id': 14198,
#     u'uri': u'http://knowledge.microsoft.com/mso/olympics.bidding_city.city_bid'},
#    {u'id': 14704,
#     u'uri': u'http://knowledge.microsoft.com/mso/local.entity.location'},
#    {u'id': 14019,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.founder.organizations_founded'},
#    {u'id': 14475,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.program.air_date_of_first_episode'},
#    {u'id': 14907,
#     u'uri': u'http://knowledge.microsoft.com/mso/interests.collection_category.name_of_collection_activity'},
#    {u'id': 14906,
#     u'uri': u'http://knowledge.microsoft.com/mso/aviation.airline.icao_airline_designator'},
#    {u'id': 13649,
#     u'uri': u'http://knowledge.microsoft.com/mso/book.publishing_company.isfdb_id'},
#    {u'id': 14323,
#     u'uri': u'http://knowledge.microsoft.com/mso/language.token.referenced_entity'},
#    {u'id': 13643,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.employer.employment_tenure'},
#    {u'id': 14147,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.operation.operating_income'},
#    {u'id': 14126,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.person.quotation'},
#    {u'id': 14170,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.city_fuel_economy'},
#    {u'id': 13774,
#     u'uri': u'http://knowledge.microsoft.com/mso/military.combatant.force_deployments'},
#    {u'id': 13918,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.secondary_income'},
#    {u'id': 14485,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.program.series_episode'},
#    {u'id': 14781,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.stock_ticker_symbol.issue'},
#    {u'id': 14181,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.city_fuel_economy_minimum'},
#    {u'id': 13994,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.health_group.adolescent_fertility_rate_per_thousand'},
#    {u'id': 14976,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.icd_9_cm_classification.parent_classification'},
#    {u'id': 15076,
#     u'uri': u'http://knowledge.microsoft.com/mso/law.attorney.business'},
#    {u'id': 14411,
#     u'uri': u'http://knowledge.microsoft.com/mso/ratings.rating.rating_value'},
#    {u'id': 14659,
#     u'uri': u'http://knowledge.microsoft.com/mso/computer.computer.manufacturer_brand'},
#    {u'id': 14768,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.drug_brand.manufacturer'},
#    {u'id': 14554,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.program_guest.appeared_on'},
#    {u'id': 15204,
#     u'uri': u'http://knowledge.microsoft.com/mso/broadcast.radio_network.affiliates'},
#    {u'id': 13698,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.scope.organizations_with_this_scope'},
#    {u'id': 13983,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.gdp_growth_rate'},
#    {u'id': 14449,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.computer_videogame.prequel'},
#    {u'id': 13968,
#     u'uri': u'http://knowledge.microsoft.com/mso/sports.country.athletes'},
#    {u'id': 13986,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.government_group.debt_service_percent_trade_volume'},
#    {u'id': 14086,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.income_share_lowest_10_percent'},
#    {u'id': 14134,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.person.last_name'},
#    {u'id': 14714,
#     u'uri': u'http://knowledge.microsoft.com/mso/local.entity.preferred_phone_number'},
#    {u'id': 13762,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.female_services_employees'},
#    {u'id': 14779,
#     u'uri': u'http://knowledge.microsoft.com/mso/language.human_language.region'},
#    {u'id': 13761,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.female_children_in_employment'},
#    {u'id': 14847,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.education_group.primary_trained_teachers'},
#    {u'id': 13778,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.infrastructure_group.logistics_performance_index'},
#    {u'id': 14678,
#     u'uri': u'http://knowledge.microsoft.com/mso/visual_art.art_subject.artwork'},
#    {u'id': 14383,
#     u'uri': u'http://knowledge.microsoft.com/mso/computer.software_genre.software_in_genre'},
#    {u'id': 14225,
#     u'uri': u'http://knowledge.microsoft.com/mso/computer.software.software_developer'},
#    {u'id': 15124,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.computer_game_engine_developer.computer_game_engines_developed'},
#    {u'id': 13650,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.consumer_company.company_product_relationship'},
#    {u'id': 14799,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.committee_title.committee_membership'},
#    {u'id': 13814,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.environment_group.marine_protected_areas'},
#    {u'id': 13902,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.net_inflows_portfolio_equity'},
#    {u'id': 14544,
#     u'uri': u'http://knowledge.microsoft.com/mso/government.politician.legislative_committees_served_on'},
#    {u'id': 14244,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.company_product_relationship.consumer_product'},
#    {u'id': 13696,
#     u'uri': u'http://knowledge.microsoft.com/mso/location.location.area'},
#    {u'id': 13903,
#     u'uri': u'http://knowledge.microsoft.com/mso/olympics.participating_country.ioc_code'},
#    {u'id': 13852,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.gasoline_price'},
#    {u'id': 14839,
#     u'uri': u'http://knowledge.microsoft.com/mso/type.object.adult_score'},
#    {u'id': 14820,
#     u'uri': u'http://knowledge.microsoft.com/mso/computer.computer.discontinued'},
#    {u'id': 14856,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.company_advisor.companies_advised'},
#    {u'id': 14702,
#     u'uri': u'http://knowledge.microsoft.com/dev/local.entity.preferred_fax_number'},
#    {u'id': 15006,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.manufacturing_plant.location'},
#    {u'id': 15202,
#     u'uri': u'http://knowledge.microsoft.com/mso/book.periodical_format.periodicals_in_this_format'},
#    {u'id': 14589,
#     u'uri': u'http://knowledge.microsoft.com/mso/food.food.nutrition'},
#    {u'id': 13801,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.unemployment_rate_long_term'},
#    {u'id': 13905,
#     u'uri': u'http://knowledge.microsoft.com/mso/architecture.contractor.projects'},
#    {u'id': 14105,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.government_group.legal_rights_index'},
#    {u'id': 14006,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.male_services_employees'},
#    {u'id': 14302,
#     u'uri': u'http://knowledge.microsoft.com/mso/internet.social_network_user.social_network_key'},
#    {u'id': 14081,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.female_youth_unemployment_percentage'},
#    {u'id': 14803,
#     u'uri': u'http://knowledge.microsoft.com/mso/fictional_universe.job_title.fictional_characters_with_this_job'},
#    {u'id': 14166,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.blue_book_value_minimum'},
#    {u'id': 14657,
#     u'uri': u'http://knowledge.microsoft.com/mso/measurement_unit.dated_float.date'},
#    {u'id': 13665,
#     u'uri': u'http://knowledge.microsoft.com/mso/book.edition.retail_price'},
#    {u'id': 14466,
#     u'uri': u'http://knowledge.microsoft.com/mso/type.object.annotated_description'},
#    {u'id': 13739,
#     u'uri': u'http://knowledge.microsoft.com/mso/aviation.airport.focus_city_for'},
#    {u'id': 13816,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.market_cap_of_listed_companies_percent_gdp'},
#    {u'id': 14613,
#     u'uri': u'http://knowledge.microsoft.com/mso/projects.project_participation.project'},
#    {u'id': 13992,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.poverty_gap_2_dollars_daily'},
#    {u'id': 13839,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.ict_goods_exports'},
#    {u'id': 14076,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.net_oda_received_per_capita'},
#    {u'id': 14452,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.computer_videogame.gameplay_mode'},
#    {u'id': 13881,
#     u'uri': u'http://knowledge.microsoft.com/mso/astronomy.astronomer.astronomical_objects_discovered'},
#    {u'id': 13915,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.research_development_researchers_per_million'},
#    {u'id': 15160,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.product_theme.product_line'},
#    {u'id': 14551,
#     u'uri': u'http://knowledge.microsoft.com/mso/book.author.book_editions_published'},
#    {u'id': 14811,
#     u'uri': u'http://knowledge.microsoft.com/mso/common.phone_number.average_wait_time'},
#    {u'id': 14205,
#     u'uri': u'http://knowledge.microsoft.com/mso/travel.destination.local_transportation'},
#    {u'id': 14785,
#     u'uri': u'http://knowledge.microsoft.com/mso/computer.programming_language.parent_language'},
#    {u'id': 14188,
#     u'uri': u'http://knowledge.microsoft.com/mso/common.phone_number.label'},
#    {u'id': 14048,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.import_of_goods_and_services'},
#    {u'id': 15018,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.actor.guest_roles'},
#    {u'id': 13617,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.person.date_of_birth'},
#    {u'id': 13991,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.education_group.female_progression_secondary_school'},
#    {u'id': 14111,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.median_lead_time_to_import'},
#    {u'id': 14278,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.consumer_company.product_lines'},
#    {u'id': 13861,
#     u'uri': u'http://knowledge.microsoft.com/mso/geography.mountaineer.first_ascents'},
#    {u'id': 14027,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.education_group.total_youth_literacy_rate'},
#    {u'id': 14489,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.program.original_network'},
#    {u'id': 15048,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.product_line.themes'},
#    {u'id': 13870,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.water_sanitation_investment_private_participation'},
#    {u'id': 13934,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.population_area_elevation_below_5_meters'},
#    {u'id': 14581,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.width'},
#    {u'id': 13628,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.designer.games_designed'},
#    {u'id': 14014,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.public_spending_education_gdp_percentage'},
#    {u'id': 13932,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.female_industry_employees'},
#    {u'id': 13922,
#     u'uri': u'http://knowledge.microsoft.com/mso/fictional_universe.setting.universe'},
#    {u'id': 14998,
#     u'uri': u'http://knowledge.microsoft.com/mso/common.image.rights_holder_attribution_text'},
#    {u'id': 14933,
#     u'uri': u'http://knowledge.microsoft.com/mso/broadcast.tv_channel.to'},
#    {u'id': 15056,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.competitive_space.industry'},
#    {u'id': 14586,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.membership_organization.members'},
#    {u'id': 13670,
#     u'uri': u'http://knowledge.microsoft.com/mso/event.agent.address'},
#    {u'id': 13945,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.health_group.crude_death_rate'},
#    {u'id': 14136,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.sponsor.sponsorship'},
#    {u'id': 14283,
#     u'uri': u'http://knowledge.microsoft.com/mso/internet.social_network_user.social_network_url'},
#    {u'id': 15200,
#     u'uri': u'http://knowledge.microsoft.com/mso/book.periodical_editor.periodicals_edited'},
#    {u'id': 14275,
#     u'uri': u'http://knowledge.microsoft.com/mso/award.winning_work.honor'},
#    {u'id': 14403,
#     u'uri': u'http://knowledge.microsoft.com/mso/geography.island_group.islands_in_group'},
#    {u'id': 13990,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.urban_agglomeration_greater_1_million'},
#    {u'id': 13942,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.infrastructure_group.improved_urban_water_source'},
#    {u'id': 14409,
#     u'uri': u'http://knowledge.microsoft.com/mso/ratings.rating.number_of_ratings'},
#    {u'id': 14564,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.deceased_person.preferred_cause_of_death'},
#    {u'id': 14004,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.infrastructure_group.fossil_fuel_consumption'},
#    {u'id': 14347,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.disease.diagnostic_test_sign_free_text'},
#    {u'id': 14419,
#     u'uri': u'http://knowledge.microsoft.com/mso/common.image.webpage_url'},
#    {u'id': 14541,
#     u'uri': u'http://knowledge.microsoft.com/mso/royalty.chivalric_order_member.belongs_to_order'},
#    {u'id': 14301,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.issuer.central_index_key_number'},
#    {u'id': 13950,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.education_group.expenditure_tertiary_student_gdp_per_capita'},
#    {u'id': 15137,
#     u'uri': u'http://knowledge.microsoft.com/mso/law.patent_assignee.patents_assigned'},
#    {u'id': 13637,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.publisher.game_versions_published'},
#    {u'id': 15017,
#     u'uri': u'http://knowledge.microsoft.com/mso/common.localization.culture_code'},
#    {u'id': 13850,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.adjusted_net_national_income'},
#    {u'id': 14291,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.company.make'},
#    {u'id': 14819,
#     u'uri': u'http://knowledge.microsoft.com/mso/commerce.electronics_product.channel_access_method'},
#    {u'id': 13917,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.health_group.malnutrition_prevalence_weight_for_age'},
#    {u'id': 15086,
#     u'uri': u'http://knowledge.microsoft.com/mso/award.competitor.competitions'},
#    {u'id': 15081,
#     u'uri': u'http://knowledge.microsoft.com/mso/government.political_party.politicians_in_this_party'},
#    {u'id': 13795,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.income_share_highest_10_percent'},
#    {u'id': 13777,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.poverty_gap_national_poverty_lines'},
#    {u'id': 14889,
#     u'uri': u'http://knowledge.microsoft.com/mso/music.album.primary_release'},
#    {u'id': 13993,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.health_expenditure_per_capita'},
#    {u'id': 13864,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.government_group.military_expenditure_percentage_gdp'},
#    {u'id': 14955,
#     u'uri': u'http://knowledge.microsoft.com/mso/geography.island.body_of_water'},
#    {u'id': 13610,
#     u'uri': u'http://knowledge.microsoft.com/mso/type.object.original_name'},
#    {u'id': 14739,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.industry.sic_code'},
#    {u'id': 13624,
#     u'uri': u'http://knowledge.microsoft.com/ext/EntityTypeRanking.DomType.DomTypeLabel'},
#    {u'id': 14051,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.member.member_of'},
#    {u'id': 13557,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.company_product_line_relationship.product_line'},
#    {u'id': 14802,
#     u'uri': u'http://knowledge.microsoft.com/mso/projects.project_role.projects'},
#    {u'id': 13621,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.person.children'},
#    {u'id': 14310,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.advisor'},
#    {u'id': 14406,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.drug_pregnancy_category.country'},
#    {u'id': 15176,
#     u'uri': u'http://knowledge.microsoft.com/mso/spaceflight.astronaut.space_time_minutes'},
#    {u'id': 14381,
#     u'uri': u'http://knowledge.microsoft.com/mso/chemistry.chemical_classification.chemical_compound'},
#    {u'id': 14430,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.computer_videogame.influenced'},
#    {u'id': 14242,
#     u'uri': u'http://knowledge.microsoft.com/mso/event.action.action_handler'},
#    {u'id': 13792,
#     u'uri': u'http://knowledge.microsoft.com/mso/olympics.participating_country.games'},
#    {u'id': 13896,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.poverty_headcount_ratio_national_poverty_lines'},
#    {u'id': 13568,
#     u'uri': u'http://knowledge.microsoft.com/mso/type.object.name'},
#    {u'id': 13958,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.income_share_third_20_percent'},
#    {u'id': 14082,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.producer.programs_produced'},
#    {u'id': 14183,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.highway_fuel_economy'},
#    {u'id': 13592,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.person.marriage'},
#    {u'id': 14256,
#     u'uri': u'http://knowledge.microsoft.com/mso/commerce.company_brand_relationship.brand'},
#    {u'id': 14407,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.drug_pregnancy_category.pregnancy_risk'},
#    {u'id': 13916,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.education_group.gross_primary_enrollment'},
#    {u'id': 14975,
#     u'uri': u'http://knowledge.microsoft.com/mso/common.image.thumbnail_id'},
#    {u'id': 14260,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.focus_areas'},
#    {u'id': 15095,
#     u'uri': u'http://knowledge.microsoft.com/mso/local.entity.price_bracket'},
#    {u'id': 14148,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.slogan'},
#    {u'id': 13629,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.acquired_by'},
#    {u'id': 14258,
#     u'uri': u'http://knowledge.microsoft.com/mso/finance.stock_exchange.companies_traded'},
#    {u'id': 14436,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.computer_videogame.publisher'},
#    {u'id': 13898,
#     u'uri': u'http://knowledge.microsoft.com/mso/food.beer_country_region.beers_from_here'},
#    {u'id': 14660,
#     u'uri': u'http://knowledge.microsoft.com/ext/infobox_person.awards'},
#    {u'id': 13703,
#     u'uri': u'http://knowledge.microsoft.com/mso/government.governmental_jurisdiction.office_or_title'},
#    {u'id': 14280,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.fiscal_year_end'},
#    {u'id': 13608,
#     u'uri': u'http://knowledge.microsoft.com/ext/entitycategory.is_top_entity'},
#    {u'id': 14876,
#     u'uri': u'http://knowledge.microsoft.com/local/local.entity.normalized_name'},
#    {u'id': 14397,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.person.language'},
#    {u'id': 14677,
#     u'uri': u'http://knowledge.microsoft.com/mso/visual_art.visual_art_form.artworks'},
#    {u'id': 14806,
#     u'uri': u'http://knowledge.microsoft.com/mso/broadcast.tv_station.branding'},
#    {u'id': 13946,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.diesel_price_liter'},
#    {u'id': 14944,
#     u'uri': u'http://knowledge.microsoft.com/mso/book.written_work.previous_in_series'},
#    {u'id': 15233,
#     u'uri': u'http://knowledge.microsoft.com/mso/broadcast.cable_satellite_availability.provider'},
#    {u'id': 15062,
#     u'uri': u'http://knowledge.microsoft.com/mso/comic_books.series.continued_by'},
#    {u'id': 13988,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.energy_investment_private_participation'},
#    {u'id': 13831,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.health_group.maternal_mortality_ratio'},
#    {u'id': 14896,
#     u'uri': u'http://knowledge.microsoft.com/mso/biology.deceased_organism.place_of_death'},
#    {u'id': 13656,
#     u'uri': u'http://knowledge.microsoft.com/mso/internet.website_owner.websites_owned'},
#    {u'id': 13602,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.person.education'},
#    {u'id': 14646,
#     u'uri': u'http://knowledge.microsoft.com/mso/projects.project_participation.project_participant'},
#    {u'id': 14751,
#     u'uri': u'http://knowledge.microsoft.com/mso/visual_art.artwork.date_begun'},
#    {u'id': 14516,
#     u'uri': u'http://knowledge.microsoft.com/mso/film.film.trailer'},
#    {u'id': 13981,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.rural_population_percentage'},
#    {u'id': 13837,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.ict_goods_imports'},
#    {u'id': 14110,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.nonperforming_loans_to_total_gross'},
#    {u'id': 14326,
#     u'uri': u'http://knowledge.microsoft.com/mso/comic_books.series.created_by'},
#    {u'id': 14432,
#     u'uri': u'http://knowledge.microsoft.com/mso/ratings.rated_entity.aggregate_rating'},
#    {u'id': 13612,
#     u'uri': u'http://knowledge.microsoft.com/textPassage/type.object.tokenizedDescription'},
#    {u'id': 14650,
#     u'uri': u'http://knowledge.microsoft.com/mso/measurement_unit.dated_money_value.currency'},
#    {u'id': 13598,
#     u'uri': u'http://knowledge.microsoft.com/mso/event.agent.official_webpage'},
#    {u'id': 15020,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.program.tv_producer'},
#    {u'id': 13930,
#     u'uri': u'http://knowledge.microsoft.com/mso/education.school_mascot.school'},
#    {u'id': 14713,
#     u'uri': u'http://knowledge.microsoft.com/mso/type.object.preferred_name'},
#    {u'id': 14481,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.program.country_of_origin'},
#    {u'id': 14691,
#     u'uri': u'http://knowledge.microsoft.com/mso/local.entity.related_local_entity'},
#    {u'id': 14177,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.drivetrain'},
#    {u'id': 14213,
#     u'uri': u'http://knowledge.microsoft.com/mso/computer.software.software_license'},
#    {u'id': 14590,
#     u'uri': u'http://knowledge.microsoft.com/mso/food.candy_bar.candy_bar_manufacturer'},
#    {u'id': 14144,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.scope'},
#    {u'id': 14115,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.male_youth_unemployment_percentage'},
#    {u'id': 14526,
#     u'uri': u'http://knowledge.microsoft.com/mso/film.film.casting_director'},
#    {u'id': 14591,
#     u'uri': u'http://knowledge.microsoft.com/mso/food.food.serving_size'},
#    {u'id': 13693,
#     u'uri': u'http://knowledge.microsoft.com/mso/location.location.country'},
#    {u'id': 14716,
#     u'uri': u'http://knowledge.microsoft.com/mso/local.entity.preferred_webpage'},
#    {u'id': 14979,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.person.industry'},
#    {u'id': 14234,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.series_season.episodes'},
#    {u'id': 14576,
#     u'uri': u'http://knowledge.microsoft.com/mso/automotive.automotive_class.height'},
#    {u'id': 15100,
#     u'uri': u'http://knowledge.microsoft.com/mso/rail.railway_operator.railways'},
#    {u'id': 14892,
#     u'uri': u'http://knowledge.microsoft.com/mso/music.album.length'},
#    {u'id': 15122,
#     u'uri': u'http://knowledge.microsoft.com/mso/local.entity.contained_local_entity'},
#    {u'id': 13728,
#     u'uri': u'http://knowledge.microsoft.com/mso/sports.team_location.teams'},
#    {u'id': 14901,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.infectious_disease.infectious_agent_type'},
#    {u'id': 14008,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.foreign_direct_investment_net_inflows'},
#    {u'id': 14431,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.computer_videogame.subjects'},
#    {u'id': 14848,
#     u'uri': u'http://knowledge.microsoft.com/mso/tv.series_episode.producers'},
#    {u'id': 14031,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.net_barter_terms_of_trade_index'},
#    {u'id': 14384,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.competitive_space.market_share'},
#    {u'id': 15035,
#     u'uri': u'http://knowledge.microsoft.com/mso/internet.website_status.sites'},
#    {u'id': 13697,
#     u'uri': u'http://knowledge.microsoft.com/mso/location.location.request_taxi'},
#    {u'id': 15185,
#     u'uri': u'http://knowledge.microsoft.com/mso/conferences.conference_subject.series_of_conferences_about_this'},
#    {u'id': 14073,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.education_group.male_gross_intake_ratio'},
#    {u'id': 13807,
#     u'uri': u'http://knowledge.microsoft.com/mso/education.field_of_study.academics_in_this_field'},
#    {u'id': 14809,
#     u'uri': u'http://knowledge.microsoft.com/mso/common.phone_number.note'},
#    {u'id': 15138,
#     u'uri': u'http://knowledge.microsoft.com/mso/commerce.brand.brand_colors'},
#    {u'id': 14251,
#     u'uri': u'http://knowledge.microsoft.com/mso/time.event.start_date'},
#    {u'id': 14450,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.computer_videogame.expansions'},
#    {u'id': 14129,
#     u'uri': u'http://knowledge.microsoft.com/ext/infobox_person.birth_place'},
#    {u'id': 14102,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.environment_group.livestock_production_index'},
#    {u'id': 13660,
#     u'uri': u'http://knowledge.microsoft.com/mso/organization.organization.parent'},
#    {u'id': 14290,
#     u'uri': u'http://knowledge.microsoft.com/mso/type.object.perceived_identical_entity'},
#    {u'id': 14011,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.male_long_term_unemployment'},
#    {u'id': 15139,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.employer.number_of_part_time_employees'},
#    {u'id': 13883,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.high_tech_precent_of_manufactured_exports'},
#    {u'id': 13907,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.economic_group.rural_poverty_gap_national_lines'},
#    {u'id': 14360,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.acquisition.acquiring_company'},
#    {u'id': 14729,
#     u'uri': u'http://knowledge.microsoft.com/ext/entitycategory.food_subtype'},
#    {u'id': 15164,
#     u'uri': u'http://knowledge.microsoft.com/mso/basketball.team.historical_roster'},
#    {u'id': 13893,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.government_group.claims_on_central_government'},
#    {u'id': 14514,
#     u'uri': u'http://knowledge.microsoft.com/mso/film.release.date'},
#    {u'id': 14495,
#     u'uri': u'http://knowledge.microsoft.com/textPassage/common.text.mentioned_entity'},
#    {u'id': 14548,
#     u'uri': u'http://knowledge.microsoft.com/mso/business.shareholder.holding'},
#    {u'id': 14193,
#     u'uri': u'http://knowledge.microsoft.com/mso/location.geocode.label'},
#    {u'id': 14423,
#     u'uri': u'http://knowledge.microsoft.com/mso/broadcast.tv_station.owner'},
#    {u'id': 14717,
#     u'uri': u'http://knowledge.microsoft.com/local/local.entity.photo'},
#    {u'id': 15047,
#     u'uri': u'http://knowledge.microsoft.com/mso/education.educational_institution_campus.educational_institution'},
#    {u'id': 15067,
#     u'uri': u'http://knowledge.microsoft.com/mso/interests.collection_category.collectors'},
#    {u'id': 15188,
#     u'uri': u'http://knowledge.microsoft.com/mso/media_common.quotation_source.quotations'},
#    {u'id': 15069,
#     u'uri': u'http://knowledge.microsoft.com/mso/internet.social_network_user.specialization'},
#    {u'id': 13692,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.employment'},
#    {u'id': 14359,
#     u'uri': u'http://knowledge.microsoft.com/mso/medicine.disease.diagnostic_test_sign_text'},
#    {u'id': 14474,
#     u'uri': u'http://knowledge.microsoft.com/mso/time.event.person'},
#    {u'id': 14607,
#     u'uri': u'http://knowledge.microsoft.com/mso/projects.project_participant.projects'},
#    {u'id': 14618,
#     u'uri': u'http://knowledge.microsoft.com/mso/commerce.consumer_product.category'},
#    {u'id': 15184,
#     u'uri': u'http://knowledge.microsoft.com/mso/award.category.disciplines_or_subjects'},
#    {u'id': 14951,
#     u'uri': u'http://knowledge.microsoft.com/mso/geography.mountain.elevation'},
#    {u'id': 14128,
#     u'uri': u'http://knowledge.microsoft.com/mso/people.person.first_name'},
#    {u'id': 13691,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.environment_group.co2_emissions_industrial'},
#    {u'id': 14264,
#     u'uri': u'http://knowledge.microsoft.com/mso/games.game.genre'},
#    {u'id': 15178,
#     u'uri': u'http://knowledge.microsoft.com/mso/cvg.computer_game_distribution_system.games_distributed'},
#    {u'id': 14035,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.health_group.male_life_expectancy_birth'},
#    {u'id': 13794,
#     u'uri': u'http://knowledge.microsoft.com/mso/statistics.population_group.population_percent_internet_users'},
#    {u'id': 14593,
# ...
#    {u'id': 62, u'uri': u'http://ont.thomsonreuters.com/mdaas/instrumentCount'},
#    {u'id': 66, u'uri': u'http://ont.thomsonreuters.com/mdaas/primaryIndustry'},
#    {u'id': 108, u'uri': u'http://ont.thomsonreuters.com/mdaas/CIK'},
#    {u'id': 73,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/hasUltimateParent'},
#    {u'id': 118,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/PrimaryReportingEntityCode'},
#    {u'id': 46,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/dbaNameTransliterated'},
#    {u'id': 47,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/akaNameTransliterated'},
#    {u'id': 90, u'uri': u'http://ont.thomsonreuters.com/mdaas/dbaName'},
#    {u'id': 68, u'uri': u'http://ont.thomsonreuters.com/mdaas/akaName'},
#    {u'id': 104, u'uri': u'http://ont.thomsonreuters.com/mdaas/SDCusip'},
#    {u'id': 117, u'uri': u'http://rdf.thomsonreuters.com/property/PermID'},
#    {u'id': 43, u'uri': u'http://ont.thomsonreuters.com/mdaas/MXID'},
#    {u'id': 42,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/organizationCity'},
#    {u'id': 107,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/entityLastReviewedDate'},
#    {u'id': 112,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/registeredPhone'},
#    {u'id': 97,
#     u'uri': u'http://rdf.thomsonreuters.com/relationship/IsSupplierOf'},
#    {u'id': 70,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/primaryInstrument'},
#    {u'id': 95,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/legalRegistrationAddressTransliterated'},
#    {u'id': 105,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/organizationAddressLine5Transliterated'},
#    {u'id': 67,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/headquartersAddress'},
#    {u'id': 41, u'uri': u'http://ont.thomsonreuters.com/mdaas/ipoDate'},
#    {u'id': 61, u'uri': u'http://ont.thomsonreuters.com/mdaas/registeredFax'},
#    {u'id': 113,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/headquartersPhone'},
#    {u'id': 96,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/organizationInactiveMonth'},
#    {u'id': 50,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/fkaNameTransliterated'}],
#   u'rdfTypes': [{u'id': 3,
#     u'mappedEntityTypeId': 16,
#     u'mappedLabelCount': 3,
#     u'mappedStitchValueCount': 1,
#     u'shortName': u'Organization',
#     u'totalCount': 5372356,
#     u'uri': u'http://ont.thomsonreuters.com/mdaas/Organization'}],
#   u'remoteContextUri': None,
#   u'uri': u'http://rdf.entagen.com/context/1464972069183/OA'},
#  {u'id': 47,
#   u'jdbcRepository': None,
#   u'lastBatchReceived': None,
#   u'name': u'StarMine CRModel India',
#   u'predicates': [{u'id': 15236,
#     u'uri': u'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#    {u'id': 15238, u'uri': u'http://www.w3.org/2000/01/rdf-schema#label'},
#    {u'id': 15237,
#     u'uri': u'http://rdf.entagen.com/context/1465460276091/StarMine+CRModel+India/property/RIC'}],
#   u'rdfTypes': [{u'id': 1938,
#     u'mappedEntityTypeId': 14,
#     u'mappedLabelCount': 1,
#     u'mappedStitchValueCount': 1,
#     u'shortName': u'RIC',
#     u'totalCount': 501,
#     u'uri': u'http://rdf.entagen.com/context/1465460276091/StarMine+CRModel+India/type/RIC'}],
#   u'remoteContextUri': None,
#   u'uri': u'http://rdf.entagen.com/context/1465460276091/StarMine+CRModel+India'},
#  {u'id': 23,
#   u'jdbcRepository': None,
#   u'lastBatchReceived': None,
#   u'name': u'PA',
#   u'predicates': [{u'id': 3480,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalyst'},
#    {u'id': 3475, u'uri': u'http://ceg.thomsonreuters.com/suffix'},
#    {u'id': 3542,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonInsiderPositionLocalOrder'},
#    {u'id': 3496,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideModifiedDateTime'},
#    {u'id': 3509,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorEndDateAsReported'},
#    {u'id': 3532,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideExecutiveOfficerPosition'},
#    {u'id': 3540,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonInsiderPosition'},
#    {u'id': 3557,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalLocalOrganizationID'},
#    {u'id': 3520, u'uri': u'http://ceg.thomsonreuters.com/PersonInsiderSource'},
#    {u'id': 3528,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideEndDate'},
#    {u'id': 3530,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideStrategistPosition'},
#    {u'id': 3521,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonInsiderModifiedDateTime'},
#    {u'id': 3481, u'uri': u'http://ceg.thomsonreuters.com/middleName'},
#    {u'id': 3464,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystCreatedDateTime'},
#    {u'id': 3508,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorShariahSupervisoryPosition'},
#    {u'id': 3536,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySidePositionOrder'},
#    {u'id': 3517,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalTitleAsReported'},
#    {u'id': 3492, u'uri': u'http://ceg.thomsonreuters.com/isDeceased'},
#    {u'id': 3465,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystOrganizationID'},
#    {u'id': 3490,
#     u'uri': u'http://rdf.thomsonreuters.com/property/EikonDesktop'},
#    {u'id': 3504,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorStartDateAsReported'},
#    {u'id': 3505,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorStartDate'},
#    {u'id': 3499,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideOrganizationID'},
#    {u'id': 3510,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorDirectorPosition'},
#    {u'id': 3483, u'uri': u'http://ceg.thomsonreuters.com/gender'},
#    {u'id': 3516,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalStartDate'},
#    {u'id': 3468, u'uri': u'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#    {u'id': 3523,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonInsiderOrganizationID'},
#    {u'id': 3513,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalPositionLocalOrder'},
#    {u'id': 3503,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorEndDate'},
#    {u'id': 3497,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideSource'},
#    {u'id': 3470,
#     u'uri': u'http://rdf.thomsonreuters.com/relationship/InsiderOrganization'},
#    {u'id': 3471,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirector'},
#    {u'id': 3463,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystSource'},
#    {u'id': 3482,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessional'},
#    {u'id': 3498,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideDetail'},
#    {u'id': 3519, u'uri': u'http://ceg.thomsonreuters.com/PersonInsiderDetail'},
#    {u'id': 3467,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystDetail'},
#    {u'id': 3541,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonInsiderPositionOrder'},
#    {u'id': 3493,
#     u'uri': u'http://rdf.thomsonreuters.com/relationship/OfficerDirectorOrganization'},
#    {u'id': 3546,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorSource'},
#    {u'id': 3550,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystStartDate'},
#    {u'id': 3529,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySidePortfolioManagerPosition'},
#    {u'id': 3506,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorPositionLocalOrder'},
#    {u'id': 3555,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystPositionLocalOrder'},
#    {u'id': 3561,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalModifiedDateTime'},
#    {u'id': 3502,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorUnknownPosition'},
#    {u'id': 3500,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideCreatedDateTime'},
#    {u'id': 3472, u'uri': u'http://ceg.thomsonreuters.com/preferredName'},
#    {u'id': 3526,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideUknownPosition'},
#    {u'id': 3548,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorLocalOrganizationID'},
#    {u'id': 3547,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorCreatedDateTime'},
#    {u'id': 3474, u'uri': u'http://ceg.thomsonreuters.com/deathDate'},
#    {u'id': 3486,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySide'},
#    {u'id': 3491, u'uri': u'http://ceg.thomsonreuters.com/status'},
#    {u'id': 3487, u'uri': u'http://ceg.thomsonreuters.com/permId'},
#    {u'id': 3477, u'uri': u'http://rdf.thomsonreuters.com/property/PermID'},
#    {u'id': 3512,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorOfficerPosition'},
#    {u'id': 3553,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystPositionOrder'},
#    {u'id': 3538,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideEconomistPosition'},
#    {u'id': 3551,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystStartDateAsReported'},
#    {u'id': 3495,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideLocalOrganizationID'},
#    {u'id': 3554,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystPositionCoverage'},
#    {u'id': 3524,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideStartDate'},
#    {u'id': 3488, u'uri': u'http://rdf.thomsonreuters.com/property/FullName'},
#    {u'id': 3515,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalPosition'},
#    {u'id': 3535,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideAnalystPosition'},
#    {u'id': 3478, u'uri': u'http://ceg.thomsonreuters.com/lastName'},
#    {u'id': 3522,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonInsiderCreatedDateTime'},
#    {u'id': 3560,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalOrganizationID'},
#    {u'id': 3525,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideStartDateAsReported'},
#    {u'id': 3556,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystEndDateAsReported'},
#    {u'id': 3518,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalEndDate'},
#    {u'id': 3501,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorPositionOrder'},
#    {u'id': 3544,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorOrganizationID'},
#    {u'id': 3552,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystPositionBroker'},
#    {u'id': 3537,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideChiefInvestmentOfficerPosition'},
#    {u'id': 3558,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalDetail'},
#    {u'id': 3543,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorDetail'},
#    {u'id': 3489, u'uri': u'http://rdf.thomsonreuters.com/property/PermIdLink'},
#    {u'id': 3476, u'uri': u'http://ceg.thomsonreuters.com/prefix'},
#    {u'id': 3494, u'uri': u'http://rdf.thomsonreuters.com/property/EikonWeb'},
#    {u'id': 3527,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideTitleAsReported'},
#    {u'id': 3559,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalSource'},
#    {u'id': 3466,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystLocalOrganizationID'},
#    {u'id': 3549,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystEndDate'},
#    {u'id': 3539,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideSalesProfessionalPosition'},
#    {u'id': 3545,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorModifiedDateTime'},
#    {u'id': 3484,
#     u'uri': u'http://rdf.thomsonreuters.com/relationship/SellSideBuySideOrganization'},
#    {u'id': 3533,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySidePositionLocalOrder'},
#    {u'id': 3511,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorTitleAsReported'},
#    {u'id': 3534,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideTraderPosition'},
#    {u'id': 3469,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonResearchAnalystModifiedDateTime'},
#    {u'id': 3507,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonOfficerDirectorVEExecutivePosition'},
#    {u'id': 3531,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonSellSideBuySideDirectorOfResearchPosition'},
#    {u'id': 3485, u'uri': u'http://ceg.thomsonreuters.com/dateOfBirth'},
#    {u'id': 3473, u'uri': u'http://ceg.thomsonreuters.com/firstName'},
#    {u'id': 3562,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalCreatedDateTime'},
#    {u'id': 3514,
#     u'uri': u'http://ceg.thomsonreuters.com/PersonLegalProfessionalPositionOrder'},
#    {u'id': 3479, u'uri': u'http://ceg.thomsonreuters.com/PersonInsider'}],
#   u'rdfTypes': [{u'id': 624,
#     u'mappedEntityTypeId': None,
#     u'mappedLabelCount': 0,
#     u'mappedStitchValueCount': 0,
#     u'shortName': u'PersonSellSideBuySide',
#     u'totalCount': 626885,
#     u'uri': u'http://ceg.thomsonreuters.com/http://ceg.thomsonreuters.com/cem/pa/PersonSellSideBuySide'},
#    {u'id': 626,
#     u'mappedEntityTypeId': None,
#     u'mappedLabelCount': 0,
#     u'mappedStitchValueCount': 0,
#     u'shortName': u'PersonLegalProfessionalDetail',
#     u'totalCount': 46821,
#     u'uri': u'http://ceg.thomsonreuters.com/http://ceg.thomsonreuters.com/cem/pa/PersonLegalProfessionalDetail'},
#    {u'id': 630,
#     u'mappedEntityTypeId': None,
#     u'mappedLabelCount': 0,
#     u'mappedStitchValueCount': 0,
#     u'shortName': u'PersonOfficerDirector',
#     u'totalCount': 2859470,
#     u'uri': u'http://ceg.thomsonreuters.com/http://ceg.thomsonreuters.com/cem/pa/PersonOfficerDirector'},
#    {u'id': 623,
#     u'mappedEntityTypeId': 4,
#     u'mappedLabelCount': 1,
#     u'mappedStitchValueCount': 0,
#     u'shortName': u'Person',
#     u'totalCount': 5328930,
#     u'uri': u'http://ceg.thomsonreuters.com/cem/pa/Person'},
#    {u'id': 632,
#     u'mappedEntityTypeId': None,
#     u'mappedLabelCount': 0,
#     u'mappedStitchValueCount': 0,
#     u'shortName': u'PersonLegalProfessional',
#     u'totalCount': 1405119,
#     u'uri': u'http://ceg.thomsonreuters.com/http://ceg.thomsonreuters.com/cem/pa/PersonLegalProfessional'},
#    {u'id': 622,
#     u'mappedEntityTypeId': None,
#     u'mappedLabelCount': 0,
#     u'mappedStitchValueCount': 0,
#     u'shortName': u'PersonResearchAnalyst',
#     u'totalCount': 1356799,
#     u'uri': u'http://ceg.thomsonreuters.com/http://ceg.thomsonreuters.com/cem/pa/PersonResearchAnalyst'},
#    {u'id': 625,
#     u'mappedEntityTypeId': None,
#     u'mappedLabelCount': 0,
#     u'mappedStitchValueCount': 0,
#     u'shortName': u'PersonOfficerDirectorDetail',
#     u'totalCount': 2467910,
#     u'uri': u'http://ceg.thomsonreuters.com/http://ceg.thomsonreuters.com/cem/pa/PersonOfficerDirectorDetail'},
#    {u'id': 627,
#     u'mappedEntityTypeId': None,
#     u'mappedLabelCount': 0,
#     u'mappedStitchValueCount': 0,
#     u'shortName': u'PersonInsider',
#     u'totalCount': 253240,
#     u'uri': u'http://ceg.thomsonreuters.com/http://ceg.thomsonreuters.com/cem/pa/PersonInsider'},
#    {u'id': 628,
#     u'mappedEntityTypeId': None,
#     u'mappedLabelCount': 0,
#     u'mappedStitchValueCount': 0,
#     u'shortName': u'PersonSellSideBuySideDetail',
#     u'totalCount': 200997,
#     u'uri': u'http://ceg.thomsonreuters.com/http://ceg.thomsonreuters.com/cem/pa/PersonSellSideBuySideDetail'},
#    {u'id': 631,
#     u'mappedEntityTypeId': None,
#     u'mappedLabelCount': 0,
#     u'mappedStitchValueCount': 0,
#     u'shortName': u'PersonResearchAnalystDetail',
#     u'totalCount': 614394,
#     u'uri': u'http://ceg.thomsonreuters.com/http://ceg.thomsonreuters.com/cem/pa/PersonResearchAnalystDetail'},
#    {u'id': 629,
#     u'mappedEntityTypeId': None,
#     u'mappedLabelCount': 0,
#     u'mappedStitchValueCount': 0,
#     u'shortName': u'PersonInsiderDetail',
#     u'totalCount': 304,
#     u'uri': u'http://ceg.thomsonreuters.com/http://ceg.thomsonreuters.com/cem/pa/PersonInsiderDetail'}],
#   u'remoteContextUri': None,
#   u'uri': u'http://rdf.entagen.com/context/1465227427131/PA3'}]

# %% [markdown]
# A sample of 'data' for a context is displayed below. 'data' is a Python list type. Each context key is an 'id'; in this case, for MyRepublic the id is 357 (useful later) in queries. Each context also consists of predicates and rdftypes. A dict of the keys for 'data' is shown below - uri, predicates, rdfTypes etc  It is useful to think of the API actions as corresponding to what's appeared on the DataFusion web interface.
# In the below, the datasource names are printed along with the associated ids. Alternatively, given that the HTTP endpoint is open and if DataFusion is logged on, click on [here](http://dds-test.thomsonreuters.com/app/api/context/list) for the context list.

# %%
n = len(data)
datasources={data[i][u'name']:data[i][u'id'] for i in range(n)}
print datasources
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-2ba8299669e2> in <module>()
# ----> 1 n = len(data)
#       2 datasources={data[i][u'name']:data[i][u'id'] for i in range(n)}
#       3 print datasources
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# Note that these datasources correspond directly to that on the interface as partly shown below. <img src="RDF_Gui1.png">

# %% [markdown]
# #### Master Entity Types
#
# Master entity types can be defined on the DataFusion web interface as below. These entity types function as nodes on the DataFusion graph, with their own specific IDs.<img src="RDF_Master.PNG" height="2"> A list of the Master entity types can be obtained by executing the code:

# %%
url_master = "http://dds-test.thomsonreuters.com/app/api/entity/types"
entity_data = retURL(url_master)

n_ent = len(entity_data)
datasources={entity_data[i][u'name']:entity_data[i][u'id'] for i in range(n_ent)}
print datasources

# %% [markdown]
# #### Examples of searches in DataFusion
#
# A few examples of searching through DataFusion are listed below:
#
# ##### i. Searching for entity in Worldcheck
#
# This is done for an entity "ASEAN COMMODITIES INC" . In the search string below, %20 is the HTML url code [click here](http://www.degraeve.com/reference/urlencoding.php) corresponding to a blank space. Other popular examples of HTML url codes are %3A to denote ":", %7C to denote '|' and %2F to denote "/".
# Context in Worldcheck is specified by "queryFilter=context%7C%7C%7CWorldcheck".
#
# We note in this case that the resulting match in Worldcheck for "ASEAN%20COMMODITIES%20INC" is 0.859 with further information on the entity as having been blacklisted by the MAS being on the ASIC list of unauthorised cold callers. If there is no matching entity in Worldcheck, an empty dataset will be returned.

# %%
check_name="ASEAN%20COMMODITIES%20INC"

url_check_1="http://dds-test.thomsonreuters.com/app/api/entity/search?searchString="+check_name+"&dir=asc&includePredicates=false"
url_check_2="&includeRelDir=false&queryFilter=context%7C%7C%7CWorldcheck&filterType=and&extraFields=further_information_attr_exact&includeHiddenFields=false"
url_check=url_check_1+url_check_2
wc_data = retURL(url_check)
print url_check
print wc_data
# Out:
# Error in HTTP call 503
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-4690097446eb> in <module>()
#       4 url_check_2="&includeRelDir=false&queryFilter=context%7C%7C%7CWorldcheck&filterType=and&extraFields=further_information_attr_exact&includeHiddenFields=false"
#       5 url_check=url_check_1+url_check_2
# ----> 6 wc_data = retURL(url_check)
#       7 print url_check
#       8 print wc_data
#
# <ipython-input-9-feba4d5f890f> in retURL(url)
#      17     except:
#      18         print 'Error in HTTP call ' + str(response.status_code )
# ---> 19     return data
#
# UnboundLocalError: local variable 'data' referenced before assignment

# %% [markdown]
# ##### ii. Searching for entities directly related to an entity in 1MDB

# %%
srchstring="Rosman%20Abdullah"
entity_type="-1"# Organization
contextID="|||1MDB"
#url_string="http://dds-test.thomsonreuters.com/app/api/entity/search/tokenize?searchString="+srchstring+"&entityTypeId="+entity_type
url_string="http://dds.thomsonreuters.com/app/api/entity/search/tokenize?searchString="+srchstring+"&entityTypeId="+entity_type

data = retURL(url_string)
print "No of matches to string is "+str(data[u'count'])
print "data token is "+str(data[u'tokenPart'])

# url_token="http://dds-test.thomsonreuters.com/app/api/entity/search?q=*%3A*&"
url_token="http://dds.thomsonreuters.com/app/api/entity/relationships?parentUrisToken="+str(data[u'tokenPart'])
# with relationships
data_2nd_pred = retURL(url_token)
print "No of 2nd order matches is "+str(len(data_2nd_pred[u'links']))
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# <ipython-input-11-c496eee97e73> in <module>()
#       5 url_string="http://dds.thomsonreuters.com/app/api/entity/search/tokenize?searchString="+srchstring+"&entityTypeId="+entity_type
#       6
# ----> 7 data = retURL(url_string)
#       8 print "No of matches to string is "+str(data[u'count'])
#       9 print "data token is "+str(data[u'tokenPart'])
#
# <ipython-input-9-feba4d5f890f> in retURL(url)
#       7 def retURL(url):
#       8     #response = requests.get(url, auth=('eric.tham@thomsonreuters.com', 'datafusion'))
# ----> 9     response = requests.get(url, auth=('Eric', 'demo4321'))
#      10     try:
#      11         if response.status_code <> 200:
#
# C:\Users\u6038155\AppData\Local\Continuum\Anaconda2\lib\site-packages\requests\api.pyc in get(url, params, **kwargs)
#      65
#      66     kwargs.setdefault('allow_redirects', True)
# ---> 67     return request('get', url, params=params, **kwargs)
#      68
#      69
#
# C:\Users\u6038155\AppData\Local\Continuum\Anaconda2\lib\site-packages\requests\api.pyc in request(method, url, **kwargs)
#      51     # cases, and look like a memory leak in others.
#      52     with sessions.Session() as session:
# ---> 53         return session.request(method=method, url=url, **kwargs)
#      54
#      55
#
# C:\Users\u6038155\AppData\Local\Continuum\Anaconda2\lib\site-packages\requests\sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# C:\Users\u6038155\AppData\Local\Continuum\Anaconda2\lib\site-packages\requests\sessions.pyc in send(self, request, **kwargs)
#     595
#     596         # Resolve redirects if allowed.
# --> 597         history = [resp for resp in gen] if allow_redirects else []
#     598
#     599         # Shuffle things around if there's history.
#
# C:\Users\u6038155\AppData\Local\Continuum\Anaconda2\lib\site-packages\requests\sessions.pyc in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, **adapter_kwargs)
#     193                 proxies=proxies,
#     194                 allow_redirects=False,
# --> 195                 **adapter_kwargs
#     196             )
#     197
#
# C:\Users\u6038155\AppData\Local\Continuum\Anaconda2\lib\site-packages\requests\sessions.pyc in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# C:\Users\u6038155\AppData\Local\Continuum\Anaconda2\lib\site-packages\requests\adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     445         except (_SSLError, _HTTPError) as e:
#     446             if isinstance(e, _SSLError):
# --> 447                 raise SSLError(e, request=request)
#     448             elif isinstance(e, ReadTimeoutError):
#     449                 raise ReadTimeout(e, request=request)
#
# SSLError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:590)

# %%
data_2nd_pred

# %% [markdown]
# ##### iii. Displaying entity properties

# %%
len(data_2nd_pred[u'entities'])
